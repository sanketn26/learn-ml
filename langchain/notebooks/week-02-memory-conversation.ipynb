# %% [markdown]
# # Week 2 — Memory & Conversational AI
#
# **Course:** LangChain for AI Applications
# **Week Focus:** Add memory to maintain context across multiple turns of conversation.
#
# ## 🎯 Learning Objectives
#
# - Understand different memory types (Buffer, Summary, Entity)
# - Build conversational chains with context
# - Manage token limits for long conversations
# - Implement persistent memory (database storage)
# - Create multi-turn customer support flows
#
# ## 🏢 Scenario
#
# Your customer has multiple issues across conversation turns:
# 1. "I can't login"
# 2. "I'm using Gmail"
# 3. "It says invalid credentials"
#
# Without memory, the agent forgets (1) and (2). With memory, it understands the full context.
#
# ## 📚 Key Concepts
#
# ### Memory Types
# - **ConversationBufferMemory**: Store all messages (simple, uses tokens)
# - **ConversationSummaryMemory**: Summarize old messages (efficient)
# - **ConversationEntityMemory**: Extract and track entities (facts)
# - **ConversationKGMemory**: Build knowledge graph (relationships)
#
# ## ✍️ Hands-on Exercises
#
# 1. Build a chatbot with buffer memory
# 2. Implement summary memory for long conversations
# 3. Create entity tracking for customer preferences
# 4. Store and retrieve memory from database
