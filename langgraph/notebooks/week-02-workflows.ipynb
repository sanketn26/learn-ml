# %% [markdown]
# # Week 2 — Multi-Step Workflows & Routing
#
# **Course:** LangGraph for Complex Workflows
# **Week Focus:** Implement conditional routing and loops in workflows.
#
# ## 🎯 Learning Objectives
#
# - Define conditional edges based on state
# - Implement retry logic
# - Handle loops and recursion
# - Manage state transitions
# - Optimize for performance
#
# ## 🏢 Scenario
#
# Content moderation workflow:
# 1. Analyze content
# 2. If unclear → Ask LLM again
# 3. If flagged → Escalate to human
# 4. If ok → Publish
# 5. Log decision
#
# This requires:
# - Conditional routing (unclear → retry)
# - Loop handling (retries)
# - Error states (escalation)
# - Final actions (publish/log)
