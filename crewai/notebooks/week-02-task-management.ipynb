# %% [markdown]
# # Week 2 — Task Management & Dependencies
#
# **Course:** Crew.ai for Multi-Agent Systems
# **Week Focus:** Define tasks and manage dependencies between agents.
#
# ## 🎯 Learning Objectives
#
# - Define clear task specifications
# - Manage task dependencies
# - Handle task sequences
# - Implement error handling
# - Optimize agent workflows
#
# ## 📋 Task Structure
#
# Each task needs:
# - **Description**: What to do
# - **Expected Output**: What success looks like
# - **Agent**: Who does it
# - **Dependencies**: What must happen first
# - **Tools**: What's available
#
# ## 🏢 Scenario
#
# Marketing campaign workflow:
# 1. Research Agent finds trends (Task 1)
# 2. Creative Agent designs campaign (Task 2 - depends on Task 1)
# 3. Copy Agent writes messaging (Task 2 parallel)
# 4. Approval Agent reviews (Task 3 - depends on 2, 2)
# 5. Launch Agent publishes (Task 4)
#
# This requires careful task orchestration!
